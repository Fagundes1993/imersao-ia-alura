# %% [markdown]
# Atividade referente a aula 04 da Imersão IA Alura Google

# %%
#Instalando o SDK do Google
# !pip install -q -U google-generativeai

# %%
#Configurações iniciais
import google.generativeai as genai

GOOGLE_API_KEY="insira sua chave aqui"
genai.configure(api_key=GOOGLE_API_KEY)

# %%
#Listando os modelos disponíveis
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
# Configuração dos parâmetros do IA Studio

generation_config = {
  "candidate_count": 1,
  "temperature": 0.5,
}

# %%
# Parâmetros de segurança

safety_settings={
    'HATE': 'BLOCK_NONE',
    'HARASSMENT': 'BLOCK_NONE',
    'SEXUAL' : 'BLOCK_NONE',
    'DANGEROUS' : 'BLOCK_NONE'
    }

# %%
# Seleção do modelo

model = genai.GenerativeModel(model_name='gemini-1.0-pro',
                                  generation_config=generation_config,
                                  safety_settings=safety_settings,)

# %%
# Teste de resposta

response = model.generate_content("Quem descobriu o Brasil?")
response.text
# Out:
# 'Pedro Álvares Cabral'

# %%
# Criação do Chatbot

chat = model.start_chat(history=[])

prompt = input('Esperando prompt: ')

while prompt != "fim":
  response = chat.send_message(prompt)
  print("Resposta:", response.text, '\n\n')
  prompt = input('Esperando prompt: ')
# Out:
# Esperando prompt: Fale sobre a banda Forrónela
# Resposta: **Forrónela**
#
# **Formação:**
#
# * Zé Hilton (vocal e sanfona)
# * Beto (triângulo e vocal)
# * Joãozinho (zabumba e vocal)
#
# **Estilo Musical:**
#
# O Forrónela é uma banda brasileira de forró pé-de-serra, um estilo tradicional do Nordeste do Brasil. Sua música é caracterizada por ritmos animados, letras românticas e melodias dançantes.
#
# **História:**
#
# A banda foi formada em 1996, em Petrolina, Pernambuco. Os três integrantes já tinham experiência em outras bandas de forró e se uniram para criar um novo projeto. O nome "Forrónela" é uma junção das palavras "forró" e "ronela", que é um tipo de instrumento de percussão usado no forró.
#
# **Sucesso:**
#
# O Forrónela rapidamente ganhou popularidade no Nordeste e em todo o Brasil. Eles lançaram vários álbuns de sucesso, incluindo "Forrónela - O Melhor do Forró" (1998), "Forrónela - Ao Vivo" (2000) e "Forrónela - Pra Valer" (2002).
#
# **Características Musicais:**
#
# A música do Forrónela é conhecida por:
#
# * Sanfona e triângulo proeminentes
# * Ritmos rápidos e dançantes
# * Letras românticas e bem-humoradas
# * Vocais harmoniosos
#
# **Legado:**
#
# O Forrónela é considerado uma das bandas mais importantes do forró pé-de-serra. Eles ajudaram a popularizar o gênero e a manter suas tradições vivas. A banda continua a se apresentar em shows e festivais em todo o Brasil.
#
# **Prêmios e Reconhecimentos:**
#
# * Prêmio da Música Brasileira de Melhor Álbum de Forró (2001)
# * Troféu Imprensa de Melhor Banda de Forró (2002)
# * Prêmio Multishow de Melhor Banda de Forró (2003)
#
#
# Esperando prompt: As informações anteriores não são acuradas
# Resposta: Sinto muito pelas informações imprecisas fornecidas anteriormente. Aqui estão as informações corrigidas sobre a banda Forrónela:
#
# **Forrónela**
#
# **Formação:**
#
# * Zé Hilton (vocal e sanfona)
# * Beto (zabumba e vocal)
# * Joãozinho (triângulo e vocal)
#
# **Estilo Musical:**
#
# O Forrónela é uma banda brasileira de forró pé-de-serra, um estilo tradicional do Nordeste do Brasil. Sua música é caracterizada por ritmos animados, letras românticas e melodias dançantes.
#
# **História:**
#
# A banda foi formada em 1996, em Petrolina, Pernambuco. Os três integrantes já tinham experiência em outras bandas de forró e se uniram para criar um novo projeto. O nome "Forrónela" é uma junção das palavras "forró" e "ronela", que é um tipo de instrumento de percussão usado no forró.
#
# **Sucesso:**
#
# O Forrónela rapidamente ganhou popularidade no Nordeste e em todo o Brasil. Eles lançaram vários álbuns de sucesso, incluindo "Forrónela - O Melhor do Forró" (1998), "Forrónela - Ao Vivo" (2000) e "Forrónela - Pra Valer" (2002).
#
# **Características Musicais:**
#
# A música do Forrónela é conhecida por:
#
# * Sanfona e zabumba proeminentes
# * Ritmos rápidos e dançantes
# * Letras românticas e bem-humoradas
# * Vocais harmoniosos
#
# **Legado:**
#
# O Forrónela é considerado uma das bandas mais importantes do forró pé-de-serra. Eles ajudaram a popularizar o gênero e a manter suas tradições vivas. A banda continua a se apresentar em shows e festivais em todo o Brasil.
#
# **Prêmios e Reconhecimentos:**
#
# * Prêmio da Música Brasileira de Melhor Álbum de Forró (2001)
# * Troféu Imprensa de Melhor Banda de Forró (2002)
# * Prêmio Multishow de Melhor Banda de Forró (2003)
#
# **Observações:**
#
# * O instrumento tocado por Beto é a zabumba, não o triângulo.
# * Joãozinho toca triângulo, não zabumba.
#
#
# Esperando prompt: fim

# %%
# Observando o histórico do chat

chat.history
# Out:
# [parts {
#    text: "Fale sobre a banda Forr\303\263nela"
#  }
#  role: "user",
#  parts {
#    text: "**Forr\303\263nela**\n\n**Forma\303\247\303\243o:**\n\n* Z\303\251 Hilton (vocal e sanfona)\n* Beto (tri\303\242ngulo e vocal)\n* Jo\303\243ozinho (zabumba e vocal)\n\n**Estilo Musical:**\n\nO Forr\303\263nela \303\251 uma banda brasileira de forr\303\263 p\303\251-de-serra, um estilo tradicional do Nordeste do Brasil. Sua m\303\272sica \303\251 caracterizada por ritmos animados, letras rom\303\242nticas e melodias dan\303\247antes.\n\n**Hist\303\263ria:**\n\nA banda foi formada em 1996, em Petrolina, Pernambuco. Os tr\303\252s integrantes j\303\241 tinham experi\303\252ncia em outras bandas de forr\303\263 e se uniram para criar um novo projeto. O nome \"Forr\303\263nela\" \303\251 uma jun\303\247\303\243o das palavras \"forr\303\263\" e \"ronela\", que \303\251 um tipo de instrumento de percuss\303\243o usado no forr\303\263.\n\n**Sucesso:**\n\nO Forr\303\263nela rapidamente ganhou popularidade no Nordeste e em todo o Brasil. Eles lan\303\247aram v\303\241rios \303\241lbuns de sucesso, incluindo \"Forr\303\263nela - O Melhor do Forr\303\263\" (1998), \"Forr\303\263nela - Ao Vivo\" (2000) e \"Forr\303\263nela - Pra Valer\" (2002).\n\n**Caracter\303\255sticas Musicais:**\n\nA m\303\272sica do Forr\303\263nela \303\251 conhecida por:\n\n* Sanfona e tri\303\242ngulo proeminentes\n* Ritmos r\303\241pidos e dan\303\247antes\n* Letras rom\303\242nticas e bem-humoradas\n* Vocais harmoniosos\n\n**Legado:**\n\nO Forr\303\263nela \303\251 considerado uma das bandas mais importantes do forr\303\263 p\303\251-de-serra. Eles ajudaram a popularizar o g\303\252nero e a manter suas tradi\303\247\303\265es vivas. A banda continua a se apresentar em shows e festivais em todo o Brasil.\n\n**Pr\303\252mios e Reconhecimentos:**\n\n* Pr\303\252mio da M\303\272sica Brasileira de Melhor \303\201lbum de Forr\303\263 (2001)\n* Trof\303\251u Imprensa de Melhor Banda de Forr\303\263 (2002)\n* Pr\303\252mio Multishow de Melhor Banda de Forr\303\263 (2003)"
#  }
#  role: "model",
#  parts {
#    text: "As informa\303\247\303\265es anteriores n\303\243o s\303\243o acuradas"
#  }
#  role: "user",
#  parts {
#    text: "Sinto muito pelas informa\303\247\303\265es imprecisas fornecidas anteriormente. Aqui est\303\243o as informa\303\247\303\265es corrigidas sobre a banda Forr\303\263nela:\n\n**Forr\303\263nela**\n\n**Forma\303\247\303\243o:**\n\n* Z\303\251 Hilton (vocal e sanfona)\n* Beto (zabumba e vocal)\n* Jo\303\243ozinho (tri\303\242ngulo e vocal)\n\n**Estilo Musical:**\n\nO Forr\303\263nela \303\251 uma banda brasileira de forr\303\263 p\303\251-de-serra, um estilo tradicional do Nordeste do Brasil. Sua m\303\272sica \303\251 caracterizada por ritmos animados, letras rom\303\242nticas e melodias dan\303\247antes.\n\n**Hist\303\263ria:**\n\nA banda foi formada em 1996, em Petrolina, Pernambuco. Os tr\303\252s integrantes j\303\241 tinham experi\303\252ncia em outras bandas de forr\303\263 e se uniram para criar um novo projeto. O nome \"Forr\303\263nela\" \303\251 uma jun\303\247\303\243o das palavras \"forr\303\263\" e \"ronela\", que \303\251 um tipo de instrumento de percuss\303\243o usado no forr\303\263.\n\n**Sucesso:**\n\nO Forr\303\263nela rapidamente ganhou popularidade no Nordeste e em todo o Brasil. Eles lan\303\247aram v\303\241rios \303\241lbuns de sucesso, incluindo \"Forr\303\263nela - O Melhor do Forr\303\263\" (1998), \"Forr\303\263nela - Ao Vivo\" (2000) e \"Forr\303\263nela - Pra Valer\" (2002).\n\n**Caracter\303\255sticas Musicais:**\n\nA m\303\272sica do Forr\303\263nela \303\251 conhecida por:\n\n* Sanfona e zabumba proeminentes\n* Ritmos r\303\241pidos e dan\303\247antes\n* Letras rom\303\242nticas e bem-humoradas\n* Vocais harmoniosos\n\n**Legado:**\n\nO Forr\303\263nela \303\251 considerado uma das bandas mais importantes do forr\303\263 p\303\251-de-serra. Eles ajudaram a popularizar o g\303\252nero e a manter suas tradi\303\247\303\265es vivas. A banda continua a se apresentar em shows e festivais em todo o Brasil.\n\n**Pr\303\252mios e Reconhecimentos:**\n\n* Pr\303\252mio da M\303\272sica Brasileira de Melhor \303\201lbum de Forr\303\263 (2001)\n* Trof\303\251u Imprensa de Melhor Banda de Forr\303\263 (2002)\n* Pr\303\252mio Multishow de Melhor Banda de Forr\303\263 (2003)\n\n**Observa\303\247\303\265es:**\n\n* O instrumento tocado por Beto \303\251 a zabumba, n\303\243o o tri\303\242ngulo.\n* Jo\303\243ozinho toca tri\303\242ngulo, n\303\243o zabumba."
#  }
#  role: "model"]

# %%
#Melhorando a visualização
#Código disponível em https://ai.google.dev/tutorials/python_quickstart#import_packages
import textwrap
from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

#Imprimindo o histórico
for message in chat.history:
  display(to_markdown(f'**{message.role}**: {message.parts[0].text}'))
  print('-------------------------------------------')
# Out:
# > **user**: Fale sobre a banda Forrónela
# -------------------------------------------
# > **model**: **Forrónela**
# >
# > **Formação:**
# >
# > * Zé Hilton (vocal e sanfona)
# > * Beto (triângulo e vocal)
# > * Joãozinho (zabumba e vocal)
# >
# > **Estilo Musical:**
# >
# > O Forrónela é uma banda brasileira de forró pé-de-serra, um estilo tradicional do Nordeste do Brasil. Sua música é caracterizada por ritmos animados, letras românticas e melodias dançantes.
# >
# > **História:**
# >
# > A banda foi formada em 1996, em Petrolina, Pernambuco. Os três integrantes já tinham experiência em outras bandas de forró e se uniram para criar um novo projeto. O nome "Forrónela" é uma junção das palavras "forró" e "ronela", que é um tipo de instrumento de percussão usado no forró.
# >
# > **Sucesso:**
# >
# > O Forrónela rapidamente ganhou popularidade no Nordeste e em todo o Brasil. Eles lançaram vários álbuns de sucesso, incluindo "Forrónela - O Melhor do Forró" (1998), "Forrónela - Ao Vivo" (2000) e "Forrónela - Pra Valer" (2002).
# >
# > **Características Musicais:**
# >
# > A música do Forrónela é conhecida por:
# >
# > * Sanfona e triângulo proeminentes
# > * Ritmos rápidos e dançantes
# > * Letras românticas e bem-humoradas
# > * Vocais harmoniosos
# >
# > **Legado:**
# >
# > O Forrónela é considerado uma das bandas mais importantes do forró pé-de-serra. Eles ajudaram a popularizar o gênero e a manter suas tradições vivas. A banda continua a se apresentar em shows e festivais em todo o Brasil.
# >
# > **Prêmios e Reconhecimentos:**
# >
# > * Prêmio da Música Brasileira de Melhor Álbum de Forró (2001)
# > * Troféu Imprensa de Melhor Banda de Forró (2002)
# > * Prêmio Multishow de Melhor Banda de Forró (2003)
# -------------------------------------------
# > **user**: As informações anteriores não são acuradas
# -------------------------------------------
# > **model**: Sinto muito pelas informações imprecisas fornecidas anteriormente. Aqui estão as informações corrigidas sobre a banda Forrónela:
# >
# > **Forrónela**
# >
# > **Formação:**
# >
# > * Zé Hilton (vocal e sanfona)
# > * Beto (zabumba e vocal)
# > * Joãozinho (triângulo e vocal)
# >
# > **Estilo Musical:**
# >
# > O Forrónela é uma banda brasileira de forró pé-de-serra, um estilo tradicional do Nordeste do Brasil. Sua música é caracterizada por ritmos animados, letras românticas e melodias dançantes.
# >
# > **História:**
# >
# > A banda foi formada em 1996, em Petrolina, Pernambuco. Os três integrantes já tinham experiência em outras bandas de forró e se uniram para criar um novo projeto. O nome "Forrónela" é uma junção das palavras "forró" e "ronela", que é um tipo de instrumento de percussão usado no forró.
# >
# > **Sucesso:**
# >
# > O Forrónela rapidamente ganhou popularidade no Nordeste e em todo o Brasil. Eles lançaram vários álbuns de sucesso, incluindo "Forrónela - O Melhor do Forró" (1998), "Forrónela - Ao Vivo" (2000) e "Forrónela - Pra Valer" (2002).
# >
# > **Características Musicais:**
# >
# > A música do Forrónela é conhecida por:
# >
# > * Sanfona e zabumba proeminentes
# > * Ritmos rápidos e dançantes
# > * Letras românticas e bem-humoradas
# > * Vocais harmoniosos
# >
# > **Legado:**
# >
# > O Forrónela é considerado uma das bandas mais importantes do forró pé-de-serra. Eles ajudaram a popularizar o gênero e a manter suas tradições vivas. A banda continua a se apresentar em shows e festivais em todo o Brasil.
# >
# > **Prêmios e Reconhecimentos:**
# >
# > * Prêmio da Música Brasileira de Melhor Álbum de Forró (2001)
# > * Troféu Imprensa de Melhor Banda de Forró (2002)
# > * Prêmio Multishow de Melhor Banda de Forró (2003)
# >
# > **Observações:**
# >
# > * O instrumento tocado por Beto é a zabumba, não o triângulo.
# > * Joãozinho toca triângulo, não zabumba.
# -------------------------------------------
