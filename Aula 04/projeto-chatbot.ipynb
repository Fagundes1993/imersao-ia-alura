# %% [markdown]
# Atividade referente a aula 04 da Imersão IA Alura Google

# %%
#Instalando o SDK do Google
# !pip install -q -U google-generativeai

# %%
#Configurações iniciais
import google.generativeai as genai

from google.colab import userdata
api_key = userdata.get("SECRET_KEY")
genai.configure(api_key=api_key)

# %%
#Listando os modelos disponíveis
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
# Configuração dos parâmetros do IA Studio

generation_config = {
  "candidate_count": 1,
  "temperature": 0.5,
}

# %%
# Parâmetros de segurança

safety_settings={
    'HATE': 'BLOCK_NONE',
    'HARASSMENT': 'BLOCK_NONE',
    'SEXUAL' : 'BLOCK_NONE',
    'DANGEROUS' : 'BLOCK_NONE'
    }

# %%
# Seleção do modelo

model = genai.GenerativeModel(model_name='gemini-1.0-pro',
                                  generation_config=generation_config,
                                  safety_settings=safety_settings,)

# %%
# Teste de resposta

response = model.generate_content("Quem descobriu o Brasil?")
response.text
# Out:
# 'Pedro Álvares Cabral'

# %%
# Criação do Chatbot

chat = model.start_chat(history=[])

prompt = input('Esperando prompt: ')

while prompt != "fim":
  response = chat.send_message(prompt)
  print("Resposta:", response.text, '\n\n')
  prompt = input('Esperando prompt: ')
# Out:
# Esperando prompt: Qual a distância máxima, média e minima da Terra para Urano
# Resposta: **Distância Máxima:** 3.150.000.000 km (21,1 UA)
#
# **Distância Média:** 2.871.000.000 km (19,2 UA)
#
# **Distância Mínima:** 2.589.000.000 km (17,3 UA)
#
# **Nota:**
#
# * UA (Unidade Astronômica) é a distância média entre a Terra e o Sol, que é de aproximadamente 150 milhões de km.
#
#
# Esperando prompt: Levando em consideração a nossa nave mais rápida atualmente, quanto tempo levaria para sair da terra até chegar em urano?
# Resposta: Considerando a nossa nave mais rápida atualmente, a **Parker Solar Probe**, que pode atingir velocidades de até 692.000 km/h, levaria aproximadamente **17 anos e 9 meses** para viajar da Terra a Urano.
#
# **Cálculo:**
#
# * Distância da Terra a Urano: 2,871 bilhões de km (média)
# * Velocidade da Parker Solar Probe: 692.000 km/h (192 km/s)
# * Tempo = Distância / Velocidade
# * Tempo = 2.871.000.000 km / 192.000 km/s
# * Tempo = 15.005.208 horas
# * Tempo = 17 anos e 9 meses (aproximadamente)
#
# **Observações:**
#
# * Este cálculo não considera quaisquer acelerações ou desacelerações durante a viagem.
# * A Parker Solar Probe não foi projetada para viagens interplanetárias e não é adequada para uma missão a Urano.
# * Outras naves espaciais mais lentas levariam muito mais tempo para chegar a Urano. Por exemplo, a Voyager 2, que viajou a Urano em 1986, levou 9 anos e meio para chegar ao planeta.
#
#
# Esperando prompt: fim

# %%
# Observando o histórico do chat

chat.history

# %%
#Melhorando a visualização
#Código disponível em https://ai.google.dev/tutorials/python_quickstart#import_packages
import textwrap
from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

#Imprimindo o histórico
for message in chat.history:
  display(to_markdown(f'**{message.role}**: {message.parts[0].text}'))
  print('-------------------------------------------')
# Out:
# > **user**: Qual a distância máxima, média e minima da Terra para Urano
# -------------------------------------------
# > **model**: **Distância Máxima:** 3.150.000.000 km (21,1 UA)
# >
# > **Distância Média:** 2.871.000.000 km (19,2 UA)
# >
# > **Distância Mínima:** 2.589.000.000 km (17,3 UA)
# >
# > **Nota:**
# >
# > * UA (Unidade Astronômica) é a distância média entre a Terra e o Sol, que é de aproximadamente 150 milhões de km.
# -------------------------------------------
# > **user**: Levando em consideração a nossa nave mais rápida atualmente, quanto tempo levaria para sair da terra até chegar em urano?
# -------------------------------------------
# > **model**: Considerando a nossa nave mais rápida atualmente, a **Parker Solar Probe**, que pode atingir velocidades de até 692.000 km/h, levaria aproximadamente **17 anos e 9 meses** para viajar da Terra a Urano.
# >
# > **Cálculo:**
# >
# > * Distância da Terra a Urano: 2,871 bilhões de km (média)
# > * Velocidade da Parker Solar Probe: 692.000 km/h (192 km/s)
# > * Tempo = Distância / Velocidade
# > * Tempo = 2.871.000.000 km / 192.000 km/s
# > * Tempo = 15.005.208 horas
# > * Tempo = 17 anos e 9 meses (aproximadamente)
# >
# > **Observações:**
# >
# > * Este cálculo não considera quaisquer acelerações ou desacelerações durante a viagem.
# > * A Parker Solar Probe não foi projetada para viagens interplanetárias e não é adequada para uma missão a Urano.
# > * Outras naves espaciais mais lentas levariam muito mais tempo para chegar a Urano. Por exemplo, a Voyager 2, que viajou a Urano em 1986, levou 9 anos e meio para chegar ao planeta.
# -------------------------------------------
